# %% [markdown]
# # Operators

# %% [markdown]
# # 1. Arithmetic Operators: Used for mathematical operations.
# ![add.jpg](attachment:6d7c1421-eb6e-475b-99d5-0ecb718acfb3.jpg)

# %%
a=10
b=5
print(a+b) #addition
print(a-b) #subraction
print(a*b) #multiplication
print(a/b) #division
print(a//b) # floordivision
print(a%b) #modulus division
print(a**b) #exponentation
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %% [markdown]
# # 2. Assignment Operators: Used to assign and update values.
#
# ![ass.jpg](attachment:a5b8734e-b52c-4f3c-8720-af24018d4903.jpg)

# %%
a=5

# %%
a=a+3  # a=a+3 or a+=3 both are same with out assigning the value again we can write in short form
a
# Out:
# 8

# %%
a+=3
a
# Out:
# 11

# %%
a-=2
a
# Out:
# 9

# %%
a*=2
a
# Out:
# 18

# %%
a//=2
a
# Out:
# 9

# %%
a%=2
a
# Out:
# 1

# %%
a**=4
a
# Out:
# 1

# %% [markdown]
#  # 3. Unary Operators: Used on a single operand. only one opertaor is called unary operator.
# ![unary.jpg](attachment:d6f59467-5d76-43ea-b62a-eba16c73cade.jpg)

# %%
a=2
a
# Out:
# 2

# %%
b=-a
b
# Out:
# -2

# %%
-b
# Out:
# 2

# %% [markdown]
# # 4.Relational (Comparison) Operators: Used to compare values.
# ![kkkk.jpg](attachment:979b7cb5-dd22-4572-92d1-271a39a3de93.jpg)

# %%
a=6
b=4

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a<=b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a!=b
# Out:
# True

# %% [markdown]
# # 5.Logical Operators: Used to combine conditional statements.
# ![log.jpg](attachment:b51bc57a-9ab6-466a-8f3d-99b69a538497.jpg)

# %% [markdown]
# ![andor.jpg](attachment:342011d7-5ed0-43ce-97da-8dd43f5e50d0.jpg)

# %%
a=6
b=5

# %%
a<4 & b>3
# Out:
# False

# %%
a<4 and b>3
# Out:
# False

# %%
a>6 or b>3
# Out:
# True

# %%
a<=6 and b>7
# Out:
# False
